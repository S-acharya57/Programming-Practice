# %%
import bst 
import matplotlib.pyplot as plt

# %%
root = bst.randomize_BST(15)
bst.inOrderTraversal(root)
# Out:
# [35 61 15 36 71 36 15 10 47 94 58 81  9 81 52]
# root-> 35
# Inserting 61
# Inserting 15
# Inserting 36
# Inserting 71
# Inserting 36
# Inserting 15
# Inserting 10
# Inserting 47
# Inserting 94
# Inserting 58
# Inserting 81
# Inserting 9
# Inserting 81
# Inserting 52
# 9, 10, 15, 35, 36, 47, 52, 58, 61, 71, 81, 94,

# %%
def plot_tree(root):
    fig, ax = plt.subplots(figsize=(12, 8))
    ax.axis('off')

    def calculate_positions(node, x=0, y=0, level=1, positions=None, parent=None):
        if positions is None:
            positions = {}

        if node is not None:
            positions[node] = (x, y)
            if parent:
                ax.plot([positions[parent][0], x], [positions[parent][1], y], color='black', linewidth=2)  # Draw lines between nodes
            # Recursively calculate positions for left and right subtrees
            horizontal_gap = 2.5 / (2 ** level)  # Adjust horizontal gap based on level
            calculate_positions(node.left, x - horizontal_gap, y - 1.5, level + 1, positions, node)
            calculate_positions(node.right, x + horizontal_gap, y - 1.5, level + 1, positions, node)
        
        return positions

    positions = calculate_positions(root)

    for node, (x, y) in positions.items():
        ax.text(x, y, str(node.data), size=14, ha='center', va='center', bbox=dict(facecolor='white', boxstyle='circle'))

    plt.tight_layout()
    plt.show()

# %%
plot_tree(root)
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_2912\2548944097.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import bst 

root = bst.randomize_BST(20)
# Out:
# [71 18 56 46 62 90 15  6 39 95 80 99 48 34 67 12 98  3 37  3]
# root-> 71
# Inserting 18
# Inserting 56
# Inserting 46
# Inserting 62
# Inserting 90
# Inserting 15
# Inserting 6
# Inserting 39
# Inserting 95
# Inserting 80
# Inserting 99
# Inserting 48
# Inserting 34
# Inserting 67
# Inserting 12
# Inserting 98
# Inserting 3
# Inserting 37
# Inserting 3

# %%
from bst import * 

plot_tree(root)
# Out:
# C:\Users\OMEN\AppData\Local\Temp\ipykernel_2912\2548944097.py:25: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
