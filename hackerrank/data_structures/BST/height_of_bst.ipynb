# %%
import bst

# %%
def get_height(root)->int:
    """Function to get the height of the binary tree 

    Arguments:
        root -- root node of the tree
    """
    # print(f'Root is {root.data}')
    if root is None:
        print(f'Returned 0')
        return 0 
    print(f'Root is {root.data}')
    
    height = 0 

    print(f'Calling left of {root.data}\n')
    left_height = get_height(root.left)
    print(f'Calling right of {root.data}\n')
    
    right_height = get_height(root.right)
    print(f'Left height of {root.data} is {left_height}')
    print(f'right height of {root.data} is {right_height}')

    print(f'{max(left_height, right_height) + 1}')
    return max(left_height, right_height) + 1

# %%
root = bst.randomize_BST(4)
# Out:
# [44 98 58 54]
# root-> 44
# Inserting 98
# Inserting 58
# Inserting 54

# %%
bst.plot_tree(root)

# %%
get_height(root)
# Out:
# Root is 44
# Calling left of 44
#
# Returned 0
# Calling right of 44
#
# Root is 98
# Calling left of 98
#
# Root is 58
# Calling left of 58
#
# Root is 54
# Calling left of 54
#
# Returned 0
# Calling right of 54
#
# Returned 0
# Left height of 54 is 0
# right height of 54 is 0
# 1
# Calling right of 58
#
# Returned 0
# Left height of 58 is 1
# right height of 58 is 0
# 2
# Calling right of 98
#
# Returned 0
# Left height of 98 is 2
# right height of 98 is 0
# 3
# Left height of 44 is 0
# right height of 44 is 3
# 4
# 4
